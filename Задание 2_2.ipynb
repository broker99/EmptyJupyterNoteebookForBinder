# %%
x = 10 
y = 25 
print(f"x={x} y={y}")
print(f"{x}+{y}={x+y} {y}-{x}={y-x} {y}*{x}={y*x} {y}/{x}={y/x}")
print(f"F={((x**2+y)*(y-1))/(x-y+y**2)}")
# Out:
# x=10 y=25
# 10+25=35 25-10=15 25*10=250 25/10=2.5
# F=4.918032786885246
