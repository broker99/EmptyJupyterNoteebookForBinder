# %%
# a)список студентов в группе можно представить в виде обычного списка т.к. его удобно изменять и сортировать
# b)список оценок студента можно представить либо в виде кортежа либо списка . зависит от того , как оценки будут
# выставляться (отдельно каждая , либо все сразу) и будет ли необходимость их редактировать
# c)данные студента: ФИО, адрес, дата рождения. такую ифнормацию думаю будет удобно хранить в словарях , где ключом
# будет либо уникальный номер студента , либо ФИО


list = [2,4,3,16]
list2 = []
dict = {}
for i in range(0,len(list)):

    for j in range(0,list[i]):
        list2.insert(j,j+1)

    dict[list[i]] = tuple(list2)
    list2.clear()
    print(dict[list[i]])
